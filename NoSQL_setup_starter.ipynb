# %% [markdown]
# # Eat Safe, Love

# %% [markdown]
# ## Part 1: Database and Jupyter Notebook Set Up

# %% [markdown]
# mongoimport --type json -d uk_food -c establishments --drop --jsonArray establishments.json

# %%
# Import dependencies
from pymongo import MongoClient
from pprint import pprint

# %%
# Create an instance of MongoClient
mongo = MongoClient(port=27017)

# %%
# confirm that our new database was created
print(mongo.list_database_names())
# Out:
# ['admin', 'autosaurus', 'config', 'epa', 'fruits_db', 'local', 'petsitly_marketing', 'travel_db', 'uk_food']

# %%
# assign the uk_food database to a variable name
db = mongo['uk_food']

# %%
# review the collections in our new database
print(db.list_collection_names())
# Out:
# ['establishments']

# %%
# review a document in the establishments collection
print(db.establishments.find_one())
# Out:
# {'_id': ObjectId('6581e8106eecb1a7d26939a9'), 'FHRSID': 551803, 'ChangesByServerID': 0, 'LocalAuthorityBusinessID': 'PI/000070948', 'BusinessName': 'The Tea Room', 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1, 'AddressLine1': 'The Pines Garden', 'AddressLine2': 'Beach Road', 'AddressLine3': 'St Margarets Bay', 'AddressLine4': 'Kent', 'PostCode': 'CT15 6DZ', 'Phone': '', 'RatingValue': '5', 'RatingKey': 'fhrs_5_en-gb', 'RatingDate': '2021-08-17T00:00:00', 'LocalAuthorityCode': '182', 'LocalAuthorityName': 'Dover', 'LocalAuthorityWebSite': 'http://www.dover.gov.uk/', 'LocalAuthorityEmailAddress': 'publicprotection@dover.gov.uk', 'scores': {'Hygiene': 0, 'Structural': 0, 'ConfidenceInManagement': 0}, 'SchemeType': 'FHRS', 'geocode': {'longitude': '1.383298', 'latitude': '51.148133'}, 'RightToReply': '', 'Distance': 4587.362402580997, 'NewRatingPending': False, 'meta': {'dataSource': None, 'extractDate': '0001-01-01T00:00:00', 'itemCount': 0, 'returncode': None, 'totalCount': 0, 'totalPages': 0, 'pageSize': 0, 'pageNumber': 0}, 'links': [{'rel': 'self', 'href': 'https://api.ratings.food.gov.uk/establishments/551803'}]}

# %%
# assign the collection to a variable
establishments = db['establishments']

# %% [markdown]
# ## Part 2: Update the Database

# %% [markdown]
# 1. An exciting new halal restaurant just opened in Greenwich, but hasn't been rated yet. The magazine has asked you to include it in your analysis. Add the following restaurant "Penang Flavours" to the database.

# %%
# Create a dictionary for the new restaurant data
penang = {
    "BusinessName":"Penang Flavours",
    "BusinessType":"Restaurant/Cafe/Canteen",
    "BusinessTypeID":"",
    "AddressLine1":"Penang Flavours",
    "AddressLine2":"146A Plumstead Rd",
    "AddressLine3":"London",
    "AddressLine4":"",
    "PostCode":"SE18 7DY",
    "Phone":"",
    "LocalAuthorityCode":"511",
    "LocalAuthorityName":"Greenwich",
    "LocalAuthorityWebSite":"http://www.royalgreenwich.gov.uk",
    "LocalAuthorityEmailAddress":"health@royalgreenwich.gov.uk",
    "scores":{
        "Hygiene":"",
        "Structural":"",
        "ConfidenceInManagement":""
    },
    "SchemeType":"FHRS",
    "geocode":{
        "longitude":"0.08384000",
        "latitude":"51.49014200"
    },
    "RightToReply":"",
    "Distance":4623.9723280747176,
    "NewRatingPending":True
}

# %%
# Insert the new restaurant into the collection
db.establishments.insert_one(penang)

# %%
# Check that the new restaurant was inserted
establishments.find_one({"BusinessName":"Penang Flavours"})
# Out:
# {'_id': ObjectId('6581e9c51b09404b731651ae'),
#  'BusinessName': 'Penang Flavours',
#  'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  'AddressLine1': 'Penang Flavours',
#  'AddressLine2': '146A Plumstead Rd',
#  'AddressLine3': 'London',
#  'AddressLine4': '',
#  'PostCode': 'SE18 7DY',
#  'Phone': '',
#  'LocalAuthorityCode': '511',
#  'LocalAuthorityName': 'Greenwich',
#  'LocalAuthorityWebSite': 'http://www.royalgreenwich.gov.uk',
#  'LocalAuthorityEmailAddress': 'health@royalgreenwich.gov.uk',
#  'scores': {'Hygiene': '', 'Structural': '', 'ConfidenceInManagement': ''},
#  'SchemeType': 'FHRS',
#  'geocode': {'longitude': '0.08384000', 'latitude': '51.49014200'},
#  'RightToReply': '',
#  'Distance': 4623.972328074718,
#  'NewRatingPending': True}

# %% [markdown]
# 2. Find the BusinessTypeID for "Restaurant/Cafe/Canteen" and return only the `BusinessTypeID` and `BusinessType` fields.

# %%
# Find the BusinessTypeID for "Restaurant/Cafe/Canteen" and return only the BusinessTypeID and BusinessType fields
query = {"BusinessType":"Restaurant/Cafe/Canteen"}
fields = {"BusinessType" : 1, "BusinessTypeID" : 1}

results = establishments.find(query, fields)

for result in results:
    print(result)
# Out:
# {'_id': ObjectId('6581e8106eecb1a7d26939a9'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('6581e8106eecb1a7d26939ab'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('6581e8106eecb1a7d26939ad'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('6581e8106eecb1a7d26939ae'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('6581e8106eecb1a7d26939af'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('6581e8106eecb1a7d26939b0'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('6581e8106eecb1a7d26939b5'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('6581e8106eecb1a7d26939b7'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('6581e8106eecb1a7d26939b9'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('6581e8106eecb1a7d26939bb'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('6581e8106eecb1a7d26939bc'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('6581e8106eecb1a7d26939c5'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('6581e8106eecb1a7d26939c7'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('6581e8106eecb1a7d26939c9'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('6581e8106eecb1a7d26939cd'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('6581e8106eecb1a7d26939d6'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('6581e8106eecb1a7d26939d9'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('6581e8106eecb1a7d26939dd'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('6581e8106eecb1a7d26939e0'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('6581e8106eecb1a7d26939e1'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('6581e8106eecb1a7d26939e3'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('6581e8106eecb1a7d26939e6'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('6581e8106eecb1a7d26939e7'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('6581e8106eecb1a7d26939e9'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('6581e8106eecb1a7d26939ea'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('6581e8106eecb1a7d26939ec'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('6581e8106eecb1a7d26939ed'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('6581e8106eecb1a7d26939f2'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('6581e8106eecb1a7d26939f4'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('6581e8106eecb1a7d26939fa'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('6581e8106eecb1a7d26939fb'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('6581e8106eecb1a7d26939fc'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('6581e8106eecb1a7d26939fd'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('6581e8106eecb1a7d2693a00'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('6581e8106eecb1a7d2693a01'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('6581e8106eecb1a7d2693a02'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('6581e8106eecb1a7d2693a0c'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('6581e8106eecb1a7d2693a0d'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('6581e8106eecb1a7d2693a14'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('6581e8106eecb1a7d2693a15'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('6581e8106eecb1a7d2693a18'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('6581e8106eecb1a7d2693a19'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('6581e8106eecb1a7d2693a1c'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('6581e8106eecb1a7d2693a1d'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('6581e8106eecb1a7d2693a24'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('6581e8106eecb1a7d2693a2d'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('6581e8106eecb1a7d2693a2e'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('6581e8106eecb1a7d2693a32'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('6581e8106eecb1a7d2693a33'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('6581e8106eecb1a7d2693a34'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('6581e8106eecb1a7d2693a35'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('6581e8106eecb1a7d2693a36'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('6581e8106eecb1a7d2693a37'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('6581e8106eecb1a7d2693a41'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('6581e8106eecb1a7d2693a44'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('6581e8106eecb1a7d2693a45'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('6581e8106eecb1a7d2693a48'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('6581e8106eecb1a7d2693a4e'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('6581e8106eecb1a7d2693a53'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('6581e8106eecb1a7d2693a55'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('6581e8106eecb1a7d2693a59'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('6581e8106eecb1a7d2693a5a'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('6581e8106eecb1a7d2693a60'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('6581e8106eecb1a7d2693a64'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('6581e8106eecb1a7d2693a65'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('6581e8106eecb1a7d2693a69'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('6581e8106eecb1a7d2693a6c'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('6581e8106eecb1a7d2693a70'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('6581e8106eecb1a7d2693a72'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('6581e8106eecb1a7d2693a74'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('6581e8106eecb1a7d2693a78'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('6581e8106eecb1a7d2693a7f'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('6581e8106eecb1a7d2693a81'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('6581e8106eecb1a7d2693a92'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('6581e8106eecb1a7d2693a95'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('6581e8106eecb1a7d2693a96'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('6581e8106eecb1a7d2693a98'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('6581e8106eecb1a7d2693a99'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('6581e8106eecb1a7d2693aa4'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('6581e8106eecb1a7d2693aa8'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('6581e8106eecb1a7d2693aaa'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('6581e8106eecb1a7d2693aac'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('6581e8106eecb1a7d2693aad'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('6581e8106eecb1a7d2693aba'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('6581e8106eecb1a7d2693abb'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('6581e8106eecb1a7d2693ac5'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('6581e8106eecb1a7d2693ac8'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('6581e8106eecb1a7d2693ac9'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('6581e8106eecb1a7d2693ad5'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('6581e8106eecb1a7d2693ad7'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('6581e8106eecb1a7d2693ad9'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('6581e8106eecb1a7d2693add'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('6581e8106eecb1a7d2693ae3'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('6581e8106eecb1a7d2693ae4'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('6581e8106eecb1a7d2693ae6'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('6581e8106eecb1a7d2693ae9'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('6581e8106eecb1a7d2693aeb'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('6581e8106eecb1a7d2693aed'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('6581e8106eecb1a7d2693af1'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('6581e8106eecb1a7d2693af2'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('6581e8106eecb1a7d2693af3'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('6581e8106eecb1a7d2693af5'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('6581e8106eecb1a7d2693af6'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('6581e8106eecb1a7d2693af7'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('6581e8106eecb1a7d2693afb'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('6581e8106eecb1a7d2693afc'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('6581e8106eecb1a7d2693afd'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('6581e8106eecb1a7d2693afe'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('6581e8106eecb1a7d2693b00'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('6581e8106eecb1a7d2693b07'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('6581e8106eecb1a7d2693b08'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('6581e8106eecb1a7d2693b11'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('6581e8106eecb1a7d2693b13'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('6581e8106eecb1a7d2693b16'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('6581e8106eecb1a7d2693b18'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('6581e8106eecb1a7d2693b1b'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('6581e8106eecb1a7d2693b22'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('6581e8106eecb1a7d2693b24'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('6581e8106eecb1a7d2693b25'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('6581e8106eecb1a7d2693b26'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('6581e8106eecb1a7d2693b27'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('6581e8106eecb1a7d2693b2b'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('6581e8106eecb1a7d2693b2e'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('6581e8106eecb1a7d2693b32'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('6581e8106eecb1a7d2693b33'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('6581e8106eecb1a7d2693b34'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('6581e8106eecb1a7d2693b42'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('6581e8106eecb1a7d2693b43'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('6581e8106eecb1a7d2693b49'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('6581e8106eecb1a7d2693b4a'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('6581e8106eecb1a7d2693b4b'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('6581e8106eecb1a7d2693b51'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('6581e8106eecb1a7d2693b54'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('6581e8106eecb1a7d2693b57'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('6581e8106eecb1a7d2693b58'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('6581e8106eecb1a7d2693b5e'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('6581e8106eecb1a7d2693b62'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('6581e8106eecb1a7d2693b6a'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('6581e8106eecb1a7d2693b6e'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('6581e8106eecb1a7d2693b6f'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('6581e8106eecb1a7d2693b73'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('6581e8106eecb1a7d2693b76'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('6581e8106eecb1a7d2693b79'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('6581e8106eecb1a7d2693b7d'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('6581e8106eecb1a7d2693b83'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('6581e8106eecb1a7d2693b8e'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('6581e8106eecb1a7d2693b9a'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('6581e8106eecb1a7d2693ba4'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('6581e8106eecb1a7d2693bc2'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('6581e8106eecb1a7d2693bce'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('6581e8106eecb1a7d2693bcf'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('6581e8106eecb1a7d2693bd2'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('6581e8106eecb1a7d2693bd3'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('6581e8106eecb1a7d2693bd6'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('6581e8106eecb1a7d2693be3'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('6581e8106eecb1a7d2693bf7'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('6581e8106eecb1a7d2693c11'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('6581e8106eecb1a7d2693c14'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('6581e8106eecb1a7d2693c21'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('6581e8106eecb1a7d2693c22'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('6581e8106eecb1a7d2693c24'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('6581e8106eecb1a7d2693c27'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('6581e8106eecb1a7d2693c35'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('6581e8106eecb1a7d2693c41'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('6581e8106eecb1a7d2693c42'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('6581e8106eecb1a7d2693c47'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('6581e8106eecb1a7d2693c4d'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('6581e8106eecb1a7d2693c4e'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('6581e8106eecb1a7d2693c50'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('6581e8106eecb1a7d2693c55'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('6581e8106eecb1a7d2693c57'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('6581e8106eecb1a7d2693c5c'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('6581e8106eecb1a7d2693c5f'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('6581e8106eecb1a7d2693c60'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('6581e8106eecb1a7d2693c64'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('6581e8106eecb1a7d2693c6e'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('6581e8106eecb1a7d2693c71'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('6581e8106eecb1a7d2693c7e'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('6581e8106eecb1a7d2693c83'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('6581e8106eecb1a7d2693c84'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('6581e8106eecb1a7d2693c8c'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('6581e8106eecb1a7d2693c90'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('6581e8106eecb1a7d2693c98'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('6581e8106eecb1a7d2693c9d'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('6581e8106eecb1a7d2693ca0'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('6581e8106eecb1a7d2693ca1'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('6581e8106eecb1a7d2693ca2'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('6581e8106eecb1a7d2693cb2'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('6581e8106eecb1a7d2693cb9'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('6581e8106eecb1a7d2693cbc'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('6581e8106eecb1a7d2693cbf'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('6581e8106eecb1a7d2693cc0'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('6581e8106eecb1a7d2693cc5'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('6581e8106eecb1a7d2693cc6'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('6581e8106eecb1a7d2693cd5'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('6581e8106eecb1a7d2693cd9'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('6581e8106eecb1a7d2693cdd'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('6581e8106eecb1a7d2693ce4'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('6581e8106eecb1a7d2693ce6'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('6581e8106eecb1a7d2693cea'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('6581e8106eecb1a7d2693cec'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('6581e8106eecb1a7d2693cef'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('6581e8106eecb1a7d2693cf0'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('6581e8106eecb1a7d2693cf3'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('6581e8106eecb1a7d2693cf4'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('6581e8106eecb1a7d2693cf5'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('6581e8106eecb1a7d2693cf6'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('6581e8106eecb1a7d2693cfc'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('6581e8106eecb1a7d2693cff'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('6581e8106eecb1a7d2693d00'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('6581e8106eecb1a7d2693d05'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('6581e8106eecb1a7d2693d07'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('6581e8106eecb1a7d2693d08'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('6581e8106eecb1a7d2693d09'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('6581e8106eecb1a7d2693d0e'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('6581e8106eecb1a7d2693d10'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('6581e8106eecb1a7d2693d18'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('6581e8106eecb1a7d2693d1a'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('6581e8106eecb1a7d2693d1c'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('6581e8106eecb1a7d2693d1e'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('6581e8106eecb1a7d2693d21'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('6581e8106eecb1a7d2693d24'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('6581e8106eecb1a7d2693d25'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('6581e8106eecb1a7d2693d28'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('6581e8106eecb1a7d2693d2d'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('6581e8106eecb1a7d2693d2e'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('6581e8106eecb1a7d2693d31'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('6581e8106eecb1a7d2693d34'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('6581e8106eecb1a7d2693d36'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('6581e8106eecb1a7d2693d3b'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('6581e8106eecb1a7d2693d3c'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('6581e8106eecb1a7d2693d3d'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('6581e8106eecb1a7d2693d42'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('6581e8106eecb1a7d2693d43'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('6581e8106eecb1a7d2693d46'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('6581e8106eecb1a7d2693d49'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('6581e8106eecb1a7d2693d4c'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('6581e8106eecb1a7d2693d4e'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('6581e8106eecb1a7d2693d54'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('6581e8106eecb1a7d2693d56'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('6581e8106eecb1a7d2693d59'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('6581e8106eecb1a7d2693d61'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('6581e8106eecb1a7d2693d62'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('6581e8106eecb1a7d2693d63'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('6581e8106eecb1a7d2693d69'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('6581e8106eecb1a7d2693d6b'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('6581e8106eecb1a7d2693d6d'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('6581e8106eecb1a7d2693d71'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('6581e8106eecb1a7d2693d75'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('6581e8106eecb1a7d2693d76'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('6581e8106eecb1a7d2693d78'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('6581e8106eecb1a7d2693d79'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('6581e8106eecb1a7d2693d7a'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('6581e8106eecb1a7d2693d7d'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('6581e8106eecb1a7d2693d7e'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('6581e8106eecb1a7d2693d83'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('6581e8106eecb1a7d2693d84'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('6581e8106eecb1a7d2693d85'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('6581e8106eecb1a7d2693d88'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('6581e8106eecb1a7d2693d94'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('6581e8106eecb1a7d2693d98'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('6581e8106eecb1a7d2693d99'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('6581e8106eecb1a7d2693d9a'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('6581e8106eecb1a7d2693da1'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('6581e8106eecb1a7d2693da2'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('6581e8106eecb1a7d2693da3'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('6581e8106eecb1a7d2693da4'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('6581e8106eecb1a7d2693da6'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('6581e8106eecb1a7d2693da7'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('6581e8106eecb1a7d2693daa'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('6581e8106eecb1a7d2693dab'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('6581e8106eecb1a7d2693db0'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('6581e8106eecb1a7d2693db3'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('6581e8106eecb1a7d2693db4'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('6581e8106eecb1a7d2693dbb'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('6581e8106eecb1a7d2693dc6'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('6581e8106eecb1a7d2693dc9'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('6581e8106eecb1a7d2693ddd'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('6581e8106eecb1a7d2693de2'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('6581e8106eecb1a7d2693de4'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('6581e8106eecb1a7d2693deb'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('6581e8106eecb1a7d2693dec'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('6581e8106eecb1a7d2693df0'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('6581e8106eecb1a7d2693df4'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('6581e8106eecb1a7d2693e08'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('6581e8106eecb1a7d2693e10'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('6581e8106eecb1a7d2693e14'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('6581e8106eecb1a7d2693e15'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('6581e8106eecb1a7d2693e16'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('6581e8106eecb1a7d2693e18'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('6581e8106eecb1a7d2693e22'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('6581e8106eecb1a7d2693e25'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('6581e8106eecb1a7d2693e26'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('6581e8106eecb1a7d2693e27'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('6581e8106eecb1a7d2693e28'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('6581e8106eecb1a7d2693e29'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('6581e8106eecb1a7d2693e2a'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('6581e8106eecb1a7d2693e2c'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('6581e8106eecb1a7d2693e2e'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('6581e8106eecb1a7d2693e2f'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('6581e8106eecb1a7d2693e30'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('6581e8106eecb1a7d2693e31'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('6581e8106eecb1a7d2693e37'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('6581e8106eecb1a7d2693e40'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('6581e8106eecb1a7d2693e47'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('6581e8106eecb1a7d2693e48'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('6581e8106eecb1a7d2693e49'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('6581e8106eecb1a7d2693e4a'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('6581e8106eecb1a7d2693e4b'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('6581e8106eecb1a7d2693e4c'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('6581e8106eecb1a7d2693e4d'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('6581e8106eecb1a7d2693e4e'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('6581e8106eecb1a7d2693e4f'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('6581e8106eecb1a7d2693e51'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('6581e8106eecb1a7d2693e55'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('6581e8106eecb1a7d2693e57'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('6581e8106eecb1a7d2693e5b'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('6581e8106eecb1a7d2693e5e'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('6581e8106eecb1a7d2693e65'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('6581e8106eecb1a7d2693e66'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('6581e8106eecb1a7d2693e67'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('6581e8106eecb1a7d2693e68'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('6581e8106eecb1a7d2693e69'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('6581e8106eecb1a7d2693e6a'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('6581e8106eecb1a7d2693e6e'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('6581e8106eecb1a7d2693e71'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('6581e8106eecb1a7d2693e7b'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('6581e8106eecb1a7d2693e7c'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('6581e8106eecb1a7d2693e7e'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('6581e8106eecb1a7d2693e7f'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('6581e8106eecb1a7d2693e81'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('6581e8106eecb1a7d2693e83'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('6581e8106eecb1a7d2693e8b'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('6581e8106eecb1a7d2693e90'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('6581e8106eecb1a7d2693e92'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('6581e8106eecb1a7d2693e97'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('6581e8106eecb1a7d2693e99'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('6581e8106eecb1a7d2693e9c'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('6581e8106eecb1a7d2693ea0'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('6581e8106eecb1a7d2693ea1'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('6581e8106eecb1a7d2693ea4'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('6581e8106eecb1a7d2693eab'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('6581e8106eecb1a7d2693eb2'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('6581e8106eecb1a7d2693eb5'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('6581e8106eecb1a7d2693ebd'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('6581e8106eecb1a7d2693ec0'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('6581e8106eecb1a7d2693ec1'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('6581e8106eecb1a7d2693ec6'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('6581e8106eecb1a7d2693ece'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('6581e8106eecb1a7d2693ecf'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('6581e8106eecb1a7d2693ed4'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('6581e8106eecb1a7d2693eda'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('6581e8106eecb1a7d2693edb'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('6581e8106eecb1a7d2693edc'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('6581e8106eecb1a7d2693ede'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('6581e8106eecb1a7d2693ee2'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('6581e8106eecb1a7d2693ee4'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('6581e8106eecb1a7d2693eeb'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('6581e8106eecb1a7d2693eec'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('6581e8106eecb1a7d2693eed'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('6581e8106eecb1a7d2693ef0'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('6581e8106eecb1a7d2693ef7'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('6581e8106eecb1a7d2693efb'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('6581e8106eecb1a7d2693efc'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('6581e8106eecb1a7d2693f00'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('6581e8106eecb1a7d2693f03'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('6581e8106eecb1a7d2693f04'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('6581e8106eecb1a7d2693f05'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('6581e8106eecb1a7d2693f06'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('6581e8106eecb1a7d2693f07'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('6581e8106eecb1a7d2693f09'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('6581e8106eecb1a7d2693f0a'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('6581e8106eecb1a7d2693f0b'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('6581e8106eecb1a7d2693f0d'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('6581e8106eecb1a7d2693f10'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('6581e8106eecb1a7d2693f11'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('6581e8106eecb1a7d2693f12'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('6581e8106eecb1a7d2693f13'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('6581e8106eecb1a7d2693f14'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('6581e8106eecb1a7d2693f16'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('6581e8106eecb1a7d2693f18'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('6581e8106eecb1a7d2693f19'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('6581e8106eecb1a7d2693f1a'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('6581e8106eecb1a7d2693f1b'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('6581e8106eecb1a7d2693f1e'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('6581e8106eecb1a7d2693f20'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('6581e8106eecb1a7d2693f21'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('6581e8106eecb1a7d2693f22'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('6581e8106eecb1a7d2693f23'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('6581e8106eecb1a7d2693f26'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('6581e8106eecb1a7d2693f28'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('6581e8106eecb1a7d2693f30'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('6581e8106eecb1a7d2693f32'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('6581e8106eecb1a7d2693f33'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('6581e8106eecb1a7d2693f34'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('6581e8106eecb1a7d2693f35'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('6581e8106eecb1a7d2693f37'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('6581e8106eecb1a7d2693f3e'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('6581e8106eecb1a7d2693f3f'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('6581e8106eecb1a7d2693f43'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('6581e8106eecb1a7d2693f45'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('6581e8106eecb1a7d2693f47'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('6581e8106eecb1a7d2693f4c'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('6581e8106eecb1a7d2693f50'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('6581e8106eecb1a7d2693f53'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('6581e8106eecb1a7d2693f57'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('6581e8106eecb1a7d2693f65'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('6581e8106eecb1a7d2693f6e'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('6581e8106eecb1a7d2693f76'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('6581e8106eecb1a7d2693f7b'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('6581e8106eecb1a7d2693f7e'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('6581e8106eecb1a7d2693f80'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('6581e8106eecb1a7d2693f83'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('6581e8106eecb1a7d2693f8b'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('6581e8106eecb1a7d2693f90'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('6581e8106eecb1a7d2693f97'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('6581e8106eecb1a7d2693f98'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('6581e8106eecb1a7d2693f9a'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('6581e8106eecb1a7d2693f9c'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('6581e8106eecb1a7d2693f9e'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('6581e8106eecb1a7d2693f9f'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('6581e8106eecb1a7d2693fa3'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('6581e8106eecb1a7d2693fa7'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('6581e8106eecb1a7d2693fab'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('6581e8106eecb1a7d2693fb8'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('6581e8106eecb1a7d2693fb9'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('6581e8106eecb1a7d2693fbf'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('6581e8106eecb1a7d2693fc3'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('6581e8106eecb1a7d2693fc8'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('6581e8106eecb1a7d2693fcb'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('6581e8106eecb1a7d2693fd2'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('6581e8106eecb1a7d2693fd5'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('6581e8106eecb1a7d2693fd8'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('6581e8106eecb1a7d2693fdd'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('6581e8106eecb1a7d2693fe3'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('6581e8106eecb1a7d2693fe7'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# ...
# {'_id': ObjectId('6581e8136eecb1a7d269d2f5'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('6581e8136eecb1a7d269d2f6'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('6581e8136eecb1a7d269d2f8'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('6581e8136eecb1a7d269d2f9'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('6581e8136eecb1a7d269d2fa'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('6581e8136eecb1a7d269d2fb'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('6581e8136eecb1a7d269d2fc'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('6581e8136eecb1a7d269d301'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('6581e8136eecb1a7d269d302'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('6581e8136eecb1a7d269d307'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('6581e8136eecb1a7d269d309'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('6581e8136eecb1a7d269d30d'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('6581e8136eecb1a7d269d30f'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('6581e8136eecb1a7d269d318'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('6581e8136eecb1a7d269d31a'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('6581e8136eecb1a7d269d31b'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('6581e8136eecb1a7d269d320'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('6581e8136eecb1a7d269d321'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('6581e8136eecb1a7d269d322'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('6581e8136eecb1a7d269d323'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('6581e8136eecb1a7d269d324'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('6581e8136eecb1a7d269d325'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('6581e8136eecb1a7d269d328'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('6581e8136eecb1a7d269d32a'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('6581e8136eecb1a7d269d32d'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('6581e8136eecb1a7d269d32e'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('6581e8136eecb1a7d269d32f'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('6581e8136eecb1a7d269d330'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('6581e8136eecb1a7d269d333'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('6581e8136eecb1a7d269d335'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('6581e8136eecb1a7d269d336'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('6581e8136eecb1a7d269d337'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('6581e8136eecb1a7d269d33c'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('6581e8136eecb1a7d269d341'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('6581e8136eecb1a7d269d344'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('6581e8136eecb1a7d269d345'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('6581e8136eecb1a7d269d346'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('6581e8136eecb1a7d269d347'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('6581e8136eecb1a7d269d348'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('6581e8136eecb1a7d269d349'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('6581e8136eecb1a7d269d34f'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('6581e8136eecb1a7d269d350'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('6581e8136eecb1a7d269d35a'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('6581e8136eecb1a7d269d35d'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('6581e8136eecb1a7d269d35e'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('6581e8136eecb1a7d269d362'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('6581e8136eecb1a7d269d369'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('6581e8136eecb1a7d269d36b'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('6581e8136eecb1a7d269d373'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('6581e8136eecb1a7d269d374'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('6581e8136eecb1a7d269d375'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('6581e8136eecb1a7d269d37d'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('6581e8136eecb1a7d269d39f'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('6581e8136eecb1a7d269d3a7'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('6581e8136eecb1a7d269d3ab'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('6581e8136eecb1a7d269d3b0'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('6581e8136eecb1a7d269d3b1'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('6581e8136eecb1a7d269d3b2'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('6581e8136eecb1a7d269d3b4'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('6581e8136eecb1a7d269d3b5'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('6581e8136eecb1a7d269d3b8'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('6581e8136eecb1a7d269d3ba'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('6581e8136eecb1a7d269d3bb'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('6581e8136eecb1a7d269d3bc'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('6581e8136eecb1a7d269d3bd'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('6581e8136eecb1a7d269d3ce'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('6581e8136eecb1a7d269d3d2'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('6581e8136eecb1a7d269d3dd'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('6581e8136eecb1a7d269d3e0'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('6581e8136eecb1a7d269d3e4'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('6581e8136eecb1a7d269d3e8'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('6581e8136eecb1a7d269d3f2'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('6581e8136eecb1a7d269d3f3'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('6581e8136eecb1a7d269d3f7'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('6581e8136eecb1a7d269d3fd'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('6581e8136eecb1a7d269d3fe'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('6581e8136eecb1a7d269d400'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('6581e8136eecb1a7d269d401'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('6581e8136eecb1a7d269d402'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('6581e8136eecb1a7d269d40b'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('6581e8136eecb1a7d269d41c'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('6581e8136eecb1a7d269d41f'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('6581e8136eecb1a7d269d42a'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('6581e8136eecb1a7d269d42b'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('6581e8136eecb1a7d269d430'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('6581e8136eecb1a7d269d436'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('6581e8136eecb1a7d269d43c'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('6581e8136eecb1a7d269d43e'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('6581e8136eecb1a7d269d442'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('6581e8136eecb1a7d269d447'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('6581e8136eecb1a7d269d448'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('6581e8136eecb1a7d269d44b'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('6581e8136eecb1a7d269d44e'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('6581e8136eecb1a7d269d457'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('6581e8136eecb1a7d269d45b'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('6581e8136eecb1a7d269d45d'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('6581e8136eecb1a7d269d460'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('6581e8136eecb1a7d269d461'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('6581e8136eecb1a7d269d463'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('6581e8136eecb1a7d269d464'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('6581e8136eecb1a7d269d465'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('6581e8136eecb1a7d269d466'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('6581e8136eecb1a7d269d469'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('6581e8136eecb1a7d269d46a'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('6581e8136eecb1a7d269d46b'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('6581e8136eecb1a7d269d46d'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('6581e8136eecb1a7d269d472'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('6581e8136eecb1a7d269d473'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('6581e8136eecb1a7d269d474'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('6581e8136eecb1a7d269d476'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('6581e8136eecb1a7d269d477'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('6581e8136eecb1a7d269d479'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('6581e8136eecb1a7d269d47a'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('6581e8136eecb1a7d269d47b'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('6581e8136eecb1a7d269d47d'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('6581e8136eecb1a7d269d481'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('6581e8136eecb1a7d269d483'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('6581e8136eecb1a7d269d489'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('6581e8136eecb1a7d269d48b'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('6581e8136eecb1a7d269d48d'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('6581e8136eecb1a7d269d48e'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('6581e8136eecb1a7d269d48f'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('6581e8136eecb1a7d269d494'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('6581e8136eecb1a7d269d498'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('6581e8136eecb1a7d269d49b'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('6581e8136eecb1a7d269d4a0'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('6581e8136eecb1a7d269d4ab'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('6581e8136eecb1a7d269d4af'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('6581e8136eecb1a7d269d4b2'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('6581e8136eecb1a7d269d4b3'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('6581e8136eecb1a7d269d4b6'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('6581e8136eecb1a7d269d4b9'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('6581e8136eecb1a7d269d4c6'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('6581e8136eecb1a7d269d4d0'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('6581e8136eecb1a7d269d4d1'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('6581e8136eecb1a7d269d4d9'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('6581e8136eecb1a7d269d4e6'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('6581e8136eecb1a7d269d4eb'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('6581e8136eecb1a7d269d4f0'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('6581e8136eecb1a7d269d4f2'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('6581e8136eecb1a7d269d4f7'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('6581e8136eecb1a7d269d4fb'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('6581e8136eecb1a7d269d4fe'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('6581e8136eecb1a7d269d50a'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('6581e9c51b09404b731651ae'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': ''}

# %% [markdown]
# 3. Update the new restaurant with the `BusinessTypeID` you found.

# %%
# Update the new restaurant with the correct BusinessTypeID
establishments.update_one({"BusinessName":"Penang Flavours"}, {'$set' : {"BusinessTypeID" : 1}})

# %%
# Confirm that the new restaurant was updated
establishments.find_one({"BusinessName":"Penang Flavours"})
# Out:
# {'_id': ObjectId('6581e9c51b09404b731651ae'),
#  'BusinessName': 'Penang Flavours',
#  'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  'AddressLine1': 'Penang Flavours',
#  'AddressLine2': '146A Plumstead Rd',
#  'AddressLine3': 'London',
#  'AddressLine4': '',
#  'PostCode': 'SE18 7DY',
#  'Phone': '',
#  'LocalAuthorityCode': '511',
#  'LocalAuthorityName': 'Greenwich',
#  'LocalAuthorityWebSite': 'http://www.royalgreenwich.gov.uk',
#  'LocalAuthorityEmailAddress': 'health@royalgreenwich.gov.uk',
#  'scores': {'Hygiene': '', 'Structural': '', 'ConfidenceInManagement': ''},
#  'SchemeType': 'FHRS',
#  'geocode': {'longitude': '0.08384000', 'latitude': '51.49014200'},
#  'RightToReply': '',
#  'Distance': 4623.972328074718,
#  'NewRatingPending': True}

# %% [markdown]
# 4. The magazine is not interested in any establishments in Dover, so check how many documents contain the Dover Local Authority. Then, remove any establishments within the Dover Local Authority from the database, and check the number of documents to ensure they were deleted.

# %%
# Find how many documents have LocalAuthorityName as "Dover"
query = {"LocalAuthorityName" : "Dover"}
print(establishments.count_documents(query))
# Out:
# 994

# %%
# Delete all documents where LocalAuthorityName is "Dover"
establishments.delete_many(query)

# %%
# Check if any remaining documents include Dover
query = {"LocalAuthorityName" : "Dover"}
print(establishments.count_documents(query))
# Out:
# 0

# %%
# Check that other documents remain with 'find_one'
establishments.find_one()
# Out:
# {'_id': ObjectId('6581e8106eecb1a7d2693c8f'),
#  'FHRSID': 647177,
#  'ChangesByServerID': 0,
#  'LocalAuthorityBusinessID': 'PI/000041489',
#  'BusinessName': 'Wear Bay Bowls Club',
#  'BusinessType': 'Pub/bar/nightclub',
#  'BusinessTypeID': 7843,
#  'AddressLine1': 'Wear Bay Road',
#  'AddressLine2': 'Folkestone',
#  'AddressLine3': 'Kent',
#  'AddressLine4': '',
#  'PostCode': 'CT19 6PY',
#  'Phone': '',
#  'RatingValue': '4',
#  'RatingKey': 'fhrs_4_en-gb',
#  'RatingDate': '2014-03-31T00:00:00',
#  'LocalAuthorityCode': '188',
#  'LocalAuthorityName': 'Folkestone and Hythe',
#  'LocalAuthorityWebSite': 'http://www.folkestone-hythe.gov.uk',
#  'LocalAuthorityEmailAddress': 'foodteam@folkestone-hythe.gov.uk',
#  'scores': {'Hygiene': 5, 'Structural': 5, 'ConfidenceInManagement': 10},
#  'SchemeType': 'FHRS',
#  'geocode': {'longitude': '1.196408', 'latitude': '51.086058'},
#  'RightToReply': '',
#  'Distance': 4591.821311183521,
#  'NewRatingPending': False,
#  'meta': {'dataSource': None,
#   'extractDate': '0001-01-01T00:00:00',
#   'itemCount': 0,
#   'returncode': None,
#   'totalCount': 0,
#   'totalPages': 0,
#   'pageSize': 0,
#   'pageNumber': 0},
#  'links': [{'rel': 'self',
#    'href': 'https://api.ratings.food.gov.uk/establishments/647177'}]}

# %% [markdown]
# 5. Some of the number values are stored as strings, when they should be stored as numbers.

# %% [markdown]
# Use `update_many` to convert `latitude` and `longitude` to decimal numbers.

# %%
# Change the data type from String to Decimal for longitude and latitude
establishments.update_many({}, [
    {"$set": {"longitude": {'$toDouble' : '$longitude'}}}, 
    {"$set":{"latitude": {'$toDouble' : '$latitude'}}}
    ])

# %% [markdown]
# Use `update_many` to convert `RatingValue` to integer numbers.

# %%
# Set non 1-5 Rating Values to Null
non_ratings = ["AwaitingInspection", "Awaiting Inspection", "AwaitingPublication", "Pass", "Exempt"]
establishments.update_many({"RatingValue": {"$in": non_ratings}}, [ {'$set':{ "RatingValue" : None}} ])

# %%
# Change the data type from String to Integer for RatingValue
establishments.update_many({}, [
    {"$set": {"RatingValue": {"$toInt" : "$RatingValue"}}}
])

# %%
# Check that the coordinates and rating value are now numbers
check = establishments.find_one()

for key, value in check.items():
    print(f"{key}: {type(value)}")
# Out:
# _id: <class 'bson.objectid.ObjectId'>
# FHRSID: <class 'int'>
# ChangesByServerID: <class 'int'>
# LocalAuthorityBusinessID: <class 'str'>
# BusinessName: <class 'str'>
# BusinessType: <class 'str'>
# BusinessTypeID: <class 'int'>
# AddressLine1: <class 'str'>
# AddressLine2: <class 'str'>
# AddressLine3: <class 'str'>
# AddressLine4: <class 'str'>
# PostCode: <class 'str'>
# Phone: <class 'str'>
# RatingValue: <class 'int'>
# RatingKey: <class 'str'>
# RatingDate: <class 'str'>
# LocalAuthorityCode: <class 'str'>
# LocalAuthorityName: <class 'str'>
# LocalAuthorityWebSite: <class 'str'>
# LocalAuthorityEmailAddress: <class 'str'>
# scores: <class 'dict'>
# SchemeType: <class 'str'>
# geocode: <class 'dict'>
# RightToReply: <class 'str'>
# Distance: <class 'float'>
# NewRatingPending: <class 'bool'>
# meta: <class 'dict'>
# links: <class 'list'>
# longitude: <class 'NoneType'>
# latitude: <class 'NoneType'>
